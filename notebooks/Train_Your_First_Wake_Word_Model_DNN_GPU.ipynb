# %% [markdown]
# <a href="https://colab.research.google.com/github/bigflyy/DeepLearningWithPython/blob/main/notebooks/Train_Your_First_Wake_Word_Model_DNN_GPU.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🚀 Train Your First Custom Wake Word with Nanowakeword!
#
# Welcome to the official tutorial for **Nanowakeword**!
#
# In this notebook, we will guide you through the entire process of training a high-performance, custom wake word model from scratch. You don't need any pre-existing data—we will download everything we need and let Nanowakeword's intelligent engine do the heavy lifting.
#
# **Our goal:** Go from zero to a ready-to-use wake word model in just a few simple steps. Let's get started!

# %% [markdown]
# **Installation**

# %%
# @title Step 1: Install Nanowakeword
# We install the full [train] package to get all the necessary dependencies.

# ! pip install --no-cache-dir "nanowakeword[train]==1.3.4"
! pip install "nanowakeword[train] @ git+https://github.com/arcosoph/nanowakeword.git"
! pip install piper-tts

print("Installation complete!")
# Out:
# Collecting nanowakeword@ git+https://github.com/arcosoph/nanowakeword.git (from nanowakeword[train]@ git+https://github.com/arcosoph/nanowakeword.git)
#   Cloning https://github.com/arcosoph/nanowakeword.git to /tmp/pip-install-ha4ep1lg/nanowakeword_46e054ef915b4a75be7de39feeac674b
#   Running command git clone --filter=blob:none --quiet https://github.com/arcosoph/nanowakeword.git /tmp/pip-install-ha4ep1lg/nanowakeword_46e054ef915b4a75be7de39feeac674b
#   Resolved https://github.com/arcosoph/nanowakeword.git to commit 1b11d81c463c3093f1eb08d0e215ea7df915e48c
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: numpy<3.0,>=2.0 in /usr/local/lib/python3.12/dist-packages (from nanowakeword@ git+https://github.com/arcosoph/nanowakeword.git->nanowakeword[train]@ git+https://github.com/arcosoph/nanowakeword.git) (2.0.2)
# Collecting onnxruntime<2.0,>=1.15 (from nanowakeword@ git+https://github.com/arcosoph/nanowakeword.git->nanowakeword[train]@ git+https://github.com/arcosoph/nanowakeword.git)
#   Downloading onnxruntime-1.23.2-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (5.1 kB)
# Collecting torch<2.9,>=2.8 (from nanowakeword@ git+https://github.com/arcosoph/nanowakeword.git->nanowakeword[train]@ git+https://github.com/arcosoph/nanowakeword.git)
#   Downloading torch-2.8.0-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (30 kB)
# Collecting torchaudio<2.9,>=2.8 (from nanowakeword@ git+https://github.com/arcosoph/nanowakeword.git->nanowakeword[train]@ git+https://github.com/arcosoph/nanowakeword.git)
#   Downloading torchaudio-2.8.0-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (7.2 kB)
# Requirement already satisfied: scipy<2.0,>=1.11 in /usr/local/lib/python3.12/dist-packages (from nanowakeword@ git+https://github.com/arcosoph/nanowakeword.git->nanowakeword[train]@ git+https://github.com/arcosoph/nanowakeword.git) (1.16.3)
# Requirement already satisfied: scikit-learn<2.0,>=1.3 in /usr/local/lib/python3.12/dist-packages (from nanowakeword@ git+https://github.com/arcosoph/nanowakeword.git->nanowakeword[train]@ git+https://github.com/arcosoph/nanowakeword.git) (1.6.1)
# Collecting onnx<2.0,>=1.14 (from nanowakeword@ git+https://github.com/arcosoph/nanowakeword.git->nanowakeword[train]@ git+https://github.com/arcosoph/nanowakeword.git)
#   Downloading onnx-1.20.0-cp312-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (8.4 kB)
# Collecting acoustics<0.3,>=0.2.3 (from nanowakeword@ git+https://github.com/arcosoph/nanowakeword.git->nanowakeword[train]@ git+https://github.com/arcosoph/nanowakeword.git)
#   Downloading acoustics-0.2.6.tar.gz (3.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.5/3.5 MB 97.4 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: librosa<1.0,>=0.10 in /usr/local/lib/python3.12/dist-packages (from nanowakeword@ git+https://github.com/arcosoph/nanowakeword.git->nanowakeword[train]@ git+https://github.com/arcosoph/nanowakeword.git) (0.11.0)
# Requirement already satisfied: pydub<1.0,>=0.25 in /usr/local/lib/python3.12/dist-packages (from nanowakeword@ git+https://github.com/arcosoph/nanowakeword.git->nanowakeword[train]@ git+https://github.com/arcosoph/nanowakeword.git) (0.25.1)
# Collecting audiomentations<1.0,>=0.30 (from nanowakeword@ git+https://github.com/arcosoph/nanowakeword.git->nanowakeword[train]@ git+https://github.com/arcosoph/nanowakeword.git)
#   Downloading audiomentations-0.43.1-py3-none-any.whl.metadata (11 kB)
# Collecting torch_audiomentations<1.0,>=0.11 (from nanowakeword@ git+https://github.com/arcosoph/nanowakeword.git->nanowakeword[train]@ git+https://github.com/arcosoph/nanowakeword.git)
#   Downloading torch_audiomentations-0.12.0-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: soundfile<1.0,>=0.12 in /usr/local/lib/python3.12/dist-packages (from nanowakeword@ git+https://github.com/arcosoph/nanowakeword.git->nanowakeword[train]@ git+https://github.com/arcosoph/nanowakeword.git) (0.13.1)
# Collecting mutagen<2.0,>=1.46 (from nanowakeword@ git+https://github.com/arcosoph/nanowakeword.git->nanowakeword[train]@ git+https://github.com/arcosoph/nanowakeword.git)
#   Downloading mutagen-1.47.0-py3-none-any.whl.metadata (1.7 kB)
# Collecting phonemize<1.0,>=0.2 (from nanowakeword@ git+https://github.com/arcosoph/nanowakeword.git->nanowakeword[train]@ git+https://github.com/arcosoph/nanowakeword.git)
#   Downloading phonemize-0.2.4-py3-none-any.whl.metadata (7.7 kB)
# Collecting pronouncing<1.0,>=0.2 (from nanowakeword@ git+https://github.com/arcosoph/nanowakeword.git->nanowakeword[train]@ git+https://github.com/arcosoph/nanowakeword.git)
#   Downloading pronouncing-0.2.0.tar.gz (17 kB)
#   Preparing metadata (setup.py) ... done
# Collecting sounddevice<1.0,>=0.4.6 (from nanowakeword@ git+https://github.com/arcosoph/nanowakeword.git->nanowakeword[train]@ git+https://github.com/arcosoph/nanowakeword.git)
#   Downloading sounddevice-0.5.3-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: PyYAML<7.0,>=6.0 in /usr/local/lib/python3.12/dist-packages (from nanowakeword@ git+https://github.com/arcosoph/nanowakeword.git->nanowakeword[train]@ git+https://github.com/arcosoph/nanowakeword.git) (6.0.3)
# Requirement already satisfied: rich<14.0,>=13.0 in /usr/local/lib/python3.12/dist-packages (from nanowakeword@ git+https://github.com/arcosoph/nanowakeword.git->nanowakeword[train]@ git+https://github.com/arcosoph/nanowakeword.git) (13.9.4)
# Requirement already satisfied: tqdm<5.0,>=4.64 in /usr/local/lib/python3.12/dist-packages (from nanowakeword@ git+https://github.com/arcosoph/nanowakeword.git->nanowakeword[train]@ git+https://github.com/arcosoph/nanowakeword.git) (4.67.1)
# Requirement already satisfied: matplotlib<4.0,>=3.7 in /usr/local/lib/python3.12/dist-packages (from nanowakeword@ git+https://github.com/arcosoph/nanowakeword.git->nanowakeword[train]@ git+https://github.com/arcosoph/nanowakeword.git) (3.10.0)
# Collecting torchinfo<2.0,>=1.8 (from nanowakeword@ git+https://github.com/arcosoph/nanowakeword.git->nanowakeword[train]@ git+https://github.com/arcosoph/nanowakeword.git)
#   Downloading torchinfo-1.8.0-py3-none-any.whl.metadata (21 kB)
# Collecting torchmetrics<2.0,>=1.3 (from nanowakeword@ git+https://github.com/arcosoph/nanowakeword.git->nanowakeword[train]@ git+https://github.com/arcosoph/nanowakeword.git)
#   Downloading torchmetrics-1.8.2-py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from nanowakeword@ git+https://github.com/arcosoph/nanowakeword.git->nanowakeword[train]@ git+https://github.com/arcosoph/nanowakeword.git) (5.9.5)
# Requirement already satisfied: requests<3.0,>=2.28 in /usr/local/lib/python3.12/dist-packages (from nanowakeword@ git+https://github.com/arcosoph/nanowakeword.git->nanowakeword[train]@ git+https://github.com/arcosoph/nanowakeword.git) (2.32.4)
# Requirement already satisfied: six>=1.4.1 in /usr/local/lib/python3.12/dist-packages (from acoustics<0.3,>=0.2.3->nanowakeword@ git+https://github.com/arcosoph/nanowakeword.git->nanowakeword[train]@ git+https://github.com/arcosoph/nanowakeword.git) (1.17.0)
# Requirement already satisfied: pandas>=0.15 in /usr/local/lib/python3.12/dist-packages (from acoustics<0.3,>=0.2.3->nanowakeword@ git+https://github.com/arcosoph/nanowakeword.git->nanowakeword[train]@ git+https://github.com/arcosoph/nanowakeword.git) (2.2.2)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.12/dist-packages (from acoustics<0.3,>=0.2.3->nanowakeword@ git+https://github.com/arcosoph/nanowakeword.git->nanowakeword[train]@ git+https://github.com/arcosoph/nanowakeword.git) (0.9.0)
# Collecting numpy-minmax<1,>=0.3.0 (from audiomentations<1.0,>=0.30->nanowakeword@ git+https://github.com/arcosoph/nanowakeword.git->nanowakeword[train]@ git+https://github.com/arcosoph/nanowakeword.git)
#   Downloading numpy_minmax-0.5.0-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.0 kB)
# Collecting numpy-rms<1,>=0.4.2 (from audiomentations<1.0,>=0.30->nanowakeword@ git+https://github.com/arcosoph/nanowakeword.git->nanowakeword[train]@ git+https://github.com/arcosoph/nanowakeword.git)
#   Downloading numpy_rms-0.6.0-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.5 kB)
# Collecting python-stretch<1,>=0.3.1 (from audiomentations<1.0,>=0.30->nanowakeword@ git+https://github.com/arcosoph/nanowakeword.git->nanowakeword[train]@ git+https://github.com/arcosoph/nanowakeword.git)
#   Downloading python_stretch-0.3.1-cp312-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.7 kB)
# Collecting soxr<1.0.0,>=0.3.2 (from audiomentations<1.0,>=0.30->nanowakeword@ git+https://github.com/arcosoph/nanowakeword.git->nanowakeword[train]@ git+https://github.com/arcosoph/nanowakeword.git)
#   Downloading soxr-0.5.0.post1-cp312-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.6 kB)
# Requirement already satisfied: audioread>=2.1.9 in /usr/local/lib/python3.12/dist-packages (from librosa<1.0,>=0.10->nanowakeword@ git+https://github.com/arcosoph/nanowakeword.git->nanowakeword[train]@ git+https://github.com/arcosoph/nanowakeword.git) (3.1.0)
# Requirement already satisfied: numba>=0.51.0 in /usr/local/lib/python3.12/dist-packages (from librosa<1.0,>=0.10->nanowakeword@ git+https://github.com/arcosoph/nanowakeword.git->nanowakeword[train]@ git+https://github.com/arcosoph/nanowakeword.git) (0.60.0)
# Requirement already satisfied: joblib>=1.0 in /usr/local/lib/python3.12/dist-packages (from librosa<1.0,>=0.10->nanowakeword@ git+https://github.com/arcosoph/nanowakeword.git->nanowakeword[train]@ git+https://github.com/arcosoph/nanowakeword.git) (1.5.2)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.12/dist-packages (from librosa<1.0,>=0.10->nanowakeword@ git+https://github.com/arcosoph/nanowakeword.git->nanowakeword[train]@ git+https://github.com/arcosoph/nanowakeword.git) (4.4.2)
# Requirement already satisfied: pooch>=1.1 in /usr/local/lib/python3.12/dist-packages (from librosa<1.0,>=0.10->nanowakeword@ git+https://github.com/arcosoph/nanowakeword.git->nanowakeword[train]@ git+https://github.com/arcosoph/nanowakeword.git) (1.8.2)
# Requirement already satisfied: typing_extensions>=4.1.1 in /usr/local/lib/python3.12/dist-packages (from librosa<1.0,>=0.10->nanowakeword@ git+https://github.com/arcosoph/nanowakeword.git->nanowakeword[train]@ git+https://github.com/arcosoph/nanowakeword.git) (4.15.0)
# Requirement already satisfied: lazy_loader>=0.1 in /usr/local/lib/python3.12/dist-packages (from librosa<1.0,>=0.10->nanowakeword@ git+https://github.com/arcosoph/nanowakeword.git->nanowakeword[train]@ git+https://github.com/arcosoph/nanowakeword.git) (0.4)
# Requirement already satisfied: msgpack>=1.0 in /usr/local/lib/python3.12/dist-packages (from librosa<1.0,>=0.10->nanowakeword@ git+https://github.com/arcosoph/nanowakeword.git->nanowakeword[train]@ git+https://github.com/arcosoph/nanowakeword.git) (1.1.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib<4.0,>=3.7->nanowakeword@ git+https://github.com/arcosoph/nanowakeword.git->nanowakeword[train]@ git+https://github.com/arcosoph/nanowakeword.git) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib<4.0,>=3.7->nanowakeword@ git+https://github.com/arcosoph/nanowakeword.git->nanowakeword[train]@ git+https://github.com/arcosoph/nanowakeword.git) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib<4.0,>=3.7->nanowakeword@ git+https://github.com/arcosoph/nanowakeword.git->nanowakeword[train]@ git+https://github.com/arcosoph/nanowakeword.git) (4.61.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib<4.0,>=3.7->nanowakeword@ git+https://github.com/arcosoph/nanowakeword.git->nanowakeword[train]@ git+https://github.com/arcosoph/nanowakeword.git) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib<4.0,>=3.7->nanowakeword@ git+https://github.com/arcosoph/nanowakeword.git->nanowakeword[train]@ git+https://github.com/arcosoph/nanowakeword.git) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib<4.0,>=3.7->nanowakeword@ git+https://github.com/arcosoph/nanowakeword.git->nanowakeword[train]@ git+https://github.com/arcosoph/nanowakeword.git) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib<4.0,>=3.7->nanowakeword@ git+https://github.com/arcosoph/nanowakeword.git->nanowakeword[train]@ git+https://github.com/arcosoph/nanowakeword.git) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib<4.0,>=3.7->nanowakeword@ git+https://github.com/arcosoph/nanowakeword.git->nanowakeword[train]@ git+https://github.com/arcosoph/nanowakeword.git) (2.9.0.post0)
# Requirement already satisfied: protobuf>=4.25.1 in /usr/local/lib/python3.12/dist-packages (from onnx<2.0,>=1.14->nanowakeword@ git+https://github.com/arcosoph/nanowakeword.git->nanowakeword[train]@ git+https://github.com/arcosoph/nanowakeword.git) (5.29.5)
# Requirement already satisfied: ml_dtypes>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from onnx<2.0,>=1.14->nanowakeword@ git+https://github.com/arcosoph/nanowakeword.git->nanowakeword[train]@ git+https://github.com/arcosoph/nanowakeword.git) (0.5.4)
# Collecting coloredlogs (from onnxruntime<2.0,>=1.15->nanowakeword@ git+https://github.com/arcosoph/nanowakeword.git->nanowakeword[train]@ git+https://github.com/arcosoph/nanowakeword.git)
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.12/dist-packages (from onnxruntime<2.0,>=1.15->nanowakeword@ git+https://github.com/arcosoph/nanowakeword.git->nanowakeword[train]@ git+https://github.com/arcosoph/nanowakeword.git) (25.9.23)
# Requirement already satisfied: sympy in /usr/local/lib/python3.12/dist-packages (from onnxruntime<2.0,>=1.15->nanowakeword@ git+https://github.com/arcosoph/nanowakeword.git->nanowakeword[train]@ git+https://github.com/arcosoph/nanowakeword.git) (1.14.0)
# Collecting cmudict>=0.4.0 (from pronouncing<1.0,>=0.2->nanowakeword@ git+https://github.com/arcosoph/nanowakeword.git->nanowakeword[train]@ git+https://github.com/arcosoph/nanowakeword.git)
#   Downloading cmudict-1.1.2-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3.0,>=2.28->nanowakeword@ git+https://github.com/arcosoph/nanowakeword.git->nanowakeword[train]@ git+https://github.com/arcosoph/nanowakeword.git) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3.0,>=2.28->nanowakeword@ git+https://github.com/arcosoph/nanowakeword.git->nanowakeword[train]@ git+https://github.com/arcosoph/nanowakeword.git) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3.0,>=2.28->nanowakeword@ git+https://github.com/arcosoph/nanowakeword.git->nanowakeword[train]@ git+https://github.com/arcosoph/nanowakeword.git) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3.0,>=2.28->nanowakeword@ git+https://github.com/arcosoph/nanowakeword.git->nanowakeword[train]@ git+https://github.com/arcosoph/nanowakeword.git) (2025.11.12)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich<14.0,>=13.0->nanowakeword@ git+https://github.com/arcosoph/nanowakeword.git->nanowakeword[train]@ git+https://github.com/arcosoph/nanowakeword.git) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich<14.0,>=13.0->nanowakeword@ git+https://github.com/arcosoph/nanowakeword.git->nanowakeword[train]@ git+https://github.com/arcosoph/nanowakeword.git) (2.19.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn<2.0,>=1.3->nanowakeword@ git+https://github.com/arcosoph/nanowakeword.git->nanowakeword[train]@ git+https://github.com/arcosoph/nanowakeword.git) (3.6.0)
# Requirement already satisfied: CFFI>=1.0 in /usr/local/lib/python3.12/dist-packages (from sounddevice<1.0,>=0.4.6->nanowakeword@ git+https://github.com/arcosoph/nanowakeword.git->nanowakeword[train]@ git+https://github.com/arcosoph/nanowakeword.git) (2.0.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch<2.9,>=2.8->nanowakeword@ git+https://github.com/arcosoph/nanowakeword.git->nanowakeword[train]@ git+https://github.com/arcosoph/nanowakeword.git) (3.20.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch<2.9,>=2.8->nanowakeword@ git+https://github.com/arcosoph/nanowakeword.git->nanowakeword[train]@ git+https://github.com/arcosoph/nanowakeword.git) (75.2.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch<2.9,>=2.8->nanowakeword@ git+https://github.com/arcosoph/nanowakeword.git->nanowakeword[train]@ git+https://github.com/arcosoph/nanowakeword.git) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch<2.9,>=2.8->nanowakeword@ git+https://github.com/arcosoph/nanowakeword.git->nanowakeword[train]@ git+https://github.com/arcosoph/nanowakeword.git) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch<2.9,>=2.8->nanowakeword@ git+https://github.com/arcosoph/nanowakeword.git->nanowakeword[train]@ git+https://github.com/arcosoph/nanowakeword.git) (2025.3.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.8.93 (from torch<2.9,>=2.8->nanowakeword@ git+https://github.com/arcosoph/nanowakeword.git->nanowakeword[train]@ git+https://github.com/arcosoph/nanowakeword.git)
#   Downloading nvidia_cuda_nvrtc_cu12-12.8.93-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-cuda-runtime-cu12==12.8.90 (from torch<2.9,>=2.8->nanowakeword@ git+https://github.com/arcosoph/nanowakeword.git->nanowakeword[train]@ git+https://github.com/arcosoph/nanowakeword.git)
#   Downloading nvidia_cuda_runtime_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-cuda-cupti-cu12==12.8.90 (from torch<2.9,>=2.8->nanowakeword@ git+https://github.com/arcosoph/nanowakeword.git->nanowakeword[train]@ git+https://github.com/arcosoph/nanowakeword.git)
#   Downloading nvidia_cuda_cupti_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.7 kB)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch<2.9,>=2.8->nanowakeword@ git+https://github.com/arcosoph/nanowakeword.git->nanowakeword[train]@ git+https://github.com/arcosoph/nanowakeword.git) (9.10.2.21)
# Collecting nvidia-cublas-cu12==12.8.4.1 (from torch<2.9,>=2.8->nanowakeword@ git+https://github.com/arcosoph/nanowakeword.git->nanowakeword[train]@ git+https://github.com/arcosoph/nanowakeword.git)
#   Downloading nvidia_cublas_cu12-12.8.4.1-py3-none-manylinux_2_27_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-cufft-cu12==11.3.3.83 (from torch<2.9,>=2.8->nanowakeword@ git+https://github.com/arcosoph/nanowakeword.git->nanowakeword[train]@ git+https://github.com/arcosoph/nanowakeword.git)
#   Downloading nvidia_cufft_cu12-11.3.3.83-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-curand-cu12==10.3.9.90 (from torch<2.9,>=2.8->nanowakeword@ git+https://github.com/arcosoph/nanowakeword.git->nanowakeword[train]@ git+https://github.com/arcosoph/nanowakeword.git)
#   Downloading nvidia_curand_cu12-10.3.9.90-py3-none-manylinux_2_27_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-cusolver-cu12==11.7.3.90 (from torch<2.9,>=2.8->nanowakeword@ git+https://github.com/arcosoph/nanowakeword.git->nanowakeword[train]@ git+https://github.com/arcosoph/nanowakeword.git)
#   Downloading nvidia_cusolver_cu12-11.7.3.90-py3-none-manylinux_2_27_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-cusparse-cu12==12.5.8.93 (from torch<2.9,>=2.8->nanowakeword@ git+https://github.com/arcosoph/nanowakeword.git->nanowakeword[train]@ git+https://github.com/arcosoph/nanowakeword.git)
#   Downloading nvidia_cusparse_cu12-12.5.8.93-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.8 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch<2.9,>=2.8->nanowakeword@ git+https://github.com/arcosoph/nanowakeword.git->nanowakeword[train]@ git+https://github.com/arcosoph/nanowakeword.git) (0.7.1)
# Collecting nvidia-nccl-cu12==2.27.3 (from torch<2.9,>=2.8->nanowakeword@ git+https://github.com/arcosoph/nanowakeword.git->nanowakeword[train]@ git+https://github.com/arcosoph/nanowakeword.git)
#   Downloading nvidia_nccl_cu12-2.27.3-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.0 kB)
# Collecting nvidia-nvtx-cu12==12.8.90 (from torch<2.9,>=2.8->nanowakeword@ git+https://github.com/arcosoph/nanowakeword.git->nanowakeword[train]@ git+https://github.com/arcosoph/nanowakeword.git)
#   Downloading nvidia_nvtx_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvjitlink-cu12==12.8.93 (from torch<2.9,>=2.8->nanowakeword@ git+https://github.com/arcosoph/nanowakeword.git->nanowakeword[train]@ git+https://github.com/arcosoph/nanowakeword.git)
#   Downloading nvidia_nvjitlink_cu12-12.8.93-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-cufile-cu12==1.13.1.3 (from torch<2.9,>=2.8->nanowakeword@ git+https://github.com/arcosoph/nanowakeword.git->nanowakeword[train]@ git+https://github.com/arcosoph/nanowakeword.git)
#   Downloading nvidia_cufile_cu12-1.13.1.3-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.7 kB)
# Collecting triton==3.4.0 (from torch<2.9,>=2.8->nanowakeword@ git+https://github.com/arcosoph/nanowakeword.git->nanowakeword[train]@ git+https://github.com/arcosoph/nanowakeword.git)
#   Downloading triton-3.4.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (1.7 kB)
# Collecting julius<0.3,>=0.2.3 (from torch_audiomentations<1.0,>=0.11->nanowakeword@ git+https://github.com/arcosoph/nanowakeword.git->nanowakeword[train]@ git+https://github.com/arcosoph/nanowakeword.git)
#   Downloading julius-0.2.7.tar.gz (59 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.6/59.6 kB 6.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting torch-pitch-shift>=1.2.2 (from torch_audiomentations<1.0,>=0.11->nanowakeword@ git+https://github.com/arcosoph/nanowakeword.git->nanowakeword[train]@ git+https://github.com/arcosoph/nanowakeword.git)
#   Downloading torch_pitch_shift-1.2.5-py3-none-any.whl.metadata (2.5 kB)
# Collecting lightning-utilities>=0.8.0 (from torchmetrics<2.0,>=1.3->nanowakeword@ git+https://github.com/arcosoph/nanowakeword.git->nanowakeword[train]@ git+https://github.com/arcosoph/nanowakeword.git)
#   Downloading lightning_utilities-0.15.2-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from CFFI>=1.0->sounddevice<1.0,>=0.4.6->nanowakeword@ git+https://github.com/arcosoph/nanowakeword.git->nanowakeword[train]@ git+https://github.com/arcosoph/nanowakeword.git) (2.23)
# Requirement already satisfied: importlib-metadata>=5 in /usr/local/lib/python3.12/dist-packages (from cmudict>=0.4.0->pronouncing<1.0,>=0.2->nanowakeword@ git+https://github.com/arcosoph/nanowakeword.git->nanowakeword[train]@ git+https://github.com/arcosoph/nanowakeword.git) (8.7.0)
# Requirement already satisfied: importlib-resources>=5 in /usr/local/lib/python3.12/dist-packages (from cmudict>=0.4.0->pronouncing<1.0,>=0.2->nanowakeword@ git+https://github.com/arcosoph/nanowakeword.git->nanowakeword[train]@ git+https://github.com/arcosoph/nanowakeword.git) (6.5.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich<14.0,>=13.0->nanowakeword@ git+https://github.com/arcosoph/nanowakeword.git->nanowakeword[train]@ git+https://github.com/arcosoph/nanowakeword.git) (0.1.2)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba>=0.51.0->librosa<1.0,>=0.10->nanowakeword@ git+https://github.com/arcosoph/nanowakeword.git->nanowakeword[train]@ git+https://github.com/arcosoph/nanowakeword.git) (0.43.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=0.15->acoustics<0.3,>=0.2.3->nanowakeword@ git+https://github.com/arcosoph/nanowakeword.git->nanowakeword[train]@ git+https://github.com/arcosoph/nanowakeword.git) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=0.15->acoustics<0.3,>=0.2.3->nanowakeword@ git+https://github.com/arcosoph/nanowakeword.git->nanowakeword[train]@ git+https://github.com/arcosoph/nanowakeword.git) (2025.2)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from pooch>=1.1->librosa<1.0,>=0.10->nanowakeword@ git+https://github.com/arcosoph/nanowakeword.git->nanowakeword[train]@ git+https://github.com/arcosoph/nanowakeword.git) (4.5.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy->onnxruntime<2.0,>=1.15->nanowakeword@ git+https://github.com/arcosoph/nanowakeword.git->nanowakeword[train]@ git+https://github.com/arcosoph/nanowakeword.git) (1.3.0)
# Collecting primePy>=1.3 (from torch-pitch-shift>=1.2.2->torch_audiomentations<1.0,>=0.11->nanowakeword@ git+https://github.com/arcosoph/nanowakeword.git->nanowakeword[train]@ git+https://github.com/arcosoph/nanowakeword.git)
#   Downloading primePy-1.3-py3-none-any.whl.metadata (4.8 kB)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime<2.0,>=1.15->nanowakeword@ git+https://github.com/arcosoph/nanowakeword.git->nanowakeword[train]@ git+https://github.com/arcosoph/nanowakeword.git)
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch<2.9,>=2.8->nanowakeword@ git+https://github.com/arcosoph/nanowakeword.git->nanowakeword[train]@ git+https://github.com/arcosoph/nanowakeword.git) (3.0.3)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.12/dist-packages (from importlib-metadata>=5->cmudict>=0.4.0->pronouncing<1.0,>=0.2->nanowakeword@ git+https://github.com/arcosoph/nanowakeword.git->nanowakeword[train]@ git+https://github.com/arcosoph/nanowakeword.git) (3.23.0)
# Downloading audiomentations-0.43.1-py3-none-any.whl (86 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.1/86.1 kB 8.7 MB/s eta 0:00:00
# Downloading mutagen-1.47.0-py3-none-any.whl (194 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.4/194.4 kB 19.1 MB/s eta 0:00:00
# Downloading onnx-1.20.0-cp312-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (18.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.1/18.1 MB 124.0 MB/s eta 0:00:00
# Downloading onnxruntime-1.23.2-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (17.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.4/17.4 MB 121.6 MB/s eta 0:00:00
# Downloading phonemize-0.2.4-py3-none-any.whl (35 kB)
# Downloading sounddevice-0.5.3-py3-none-any.whl (32 kB)
# Downloading torch-2.8.0-cp312-cp312-manylinux_2_28_x86_64.whl (887.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 887.9/887.9 MB 205.6 MB/s eta 0:00:01

# %% [markdown]
# ## Step 2: Prepare the Dataset
#
# A great model starts with great data. For this tutorial, we will:
# 1.  **Download** open-source noise and Room Impulse Response (RIR) datasets.
# 2.  **Organize** all your project files within a clean, well-structured folder hierarchy for better clarity and maintainability.

# %%
# @title Step 2: Download & Prepare the SonicWeave-v1 Dataset

import os
from pathlib import Path
import subprocess
import shutil

# --- Configuration ---
DATASET_REPO_URL = "https://huggingface.co/datasets/arcosoph/SonicWeave-v1"
DATA_DIR = Path("./nanowakeword_data")

# --- Define Final Paths ---
noise_dir = DATA_DIR / "Noise"
rir_dir = DATA_DIR / "Rir"
positive_dir = DATA_DIR / "positive_wakeword"
negative_dir = DATA_DIR / "negative_speech"

# --- Main Logic ---
print("The dataset is downloading. This may take a moment...")

# Download only if the dataset folders are not already created.
if not noise_dir.exists() or not rir_dir.exists() or not any(noise_dir.iterdir()):

    # Clone the repository to a temporary location
    temp_clone_dir = DATA_DIR / "temp_repo"

    print(f"Downloading the Starter Dataset from {DATASET_REPO_URL}...")

    # --depth 1 only downloads the latest commit, which is much faster
    try:
        subprocess.run(
            ["git", "clone", "--depth", "1", DATASET_REPO_URL, str(temp_clone_dir)],
            check=True, stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL # Hide unnecessary log messages
        )
    except subprocess.CalledProcessError as e:
        print(f"Error: Failed to clone the dataset repository. Please check the URL.")
        print(f"Git command failed with error: {e}")
    else:
        print("Organizing dataset files...")

        # Move the noise and rir folders from the cloned repository to the correct location
        try:

            # Move only required folders
            for folder_name in ["Noise", "Rir"]:
                src = temp_clone_dir / folder_name
                dst = DATA_DIR / folder_name
                if src.exists():
                    shutil.move(str(src), str(dst))

            # Delete temp_repo, ignore errors if some files are locked
            shutil.rmtree(temp_clone_dir, ignore_errors=True)

            print("\nSonicWeave-v1 Dataset is ready!")
        except FileNotFoundError:
            print("Error: 'noise' or 'rir' folder not found inside the cloned repository.")
        except Exception as e:
            print(f"Error organizing files: {e}")
else:
    print("SonicWeave-v1 Dataset already found.")

# %% [markdown]
# ## Step 3: Configure and Train the Model
#
# Now for the fun part! We will create a `config.yaml` file and then run the Nanowakeword training command.

# %%
# @title Step 3.1: Create the "NanoWakeWord" Configuration File
import yaml

# Define the configuration dictionary
config_dict = {
    # ## Project & Data Paths
    # Define the project name and the locations of all data assets.
    "model_name": "arcosoph_dnn_v1",
    "output_dir": "./trained_models",

    # Source audio data paths (raw .wav files)
    "positive_data_path": str(positive_dir),
    "negative_data_path": str(negative_dir),
    "background_paths": [str(noise_dir)],
    "rir_paths": [str(rir_dir)],

    # ## Feature Manifest
    # Paths to the generated .npy feature files. The Acoustic Compositor uses these keys.
    "feature_manifest": {
        "targets": {
            "t": './trained_models/arcosoph_dnn_v1/features/positive_features_train.npy'
        },
        "negatives": {
            "n": "./trained_models/arcosoph_dnn_v1/features/negative_features_train.npy"
            # You can add unlimited additional negative sources with unique keys.
            # "my_other_negatives": "/path/to/other_negatives.npy"
        },
        "backgrounds": {
            "b": './trained_models/arcosoph_dnn_v1/features/pure_noise_features.npy'
            # For example, adding a large external noise dataset:
            # "openwakeword_noise": './openwakeword_features_ACAV100M_2000_hrs_16bit.npy'
        }
    },

    # ## Acoustic Compositor
    # Defines how to mix features from the manifest to create training scenes.
    "acoustic_compositor": {
        "use_defaults": False,
        "blueprints": [
            # 'composition' defines the scene. 'weight' defines its relative frequency.
            # You can use specific keys from the manifest (e.g., "t", "n", "openwakeword_noise", "x")
            # or general category keywords (e.g., "targets", "negatives", "backgrounds").
            # Using a category keyword like "backgrounds" will randomly select from ALL sources
            # registered under that category in the feature_manifest above.
            {"composition": ["b", "t", "b"], "weight": 40},
            {"composition": ["n", "t", "n"], "weight": 25},
            {"composition": ["n", "t", "b"], "weight": 10},
            {"composition": ["backgrounds", "t", "n"], "weight": 10},
            {"composition": ["n", "n", "n"], "weight": 30},
            {"composition": ["b", "b", "b"], "weight": 20}
            # {"composition": ["x", "my_w", "b", "best-data"], "weight": 20 } # You can add more as needed.
        ]
    },

    # ## Model Architecture
    # Configure the structure and properties of the neural network.
    "model_type": "dnn",
    "layer_size": 128,
    "n_blocks": 3,
    "embedding_dim": 64,
    "dropout_prob": 0.25,
    "activation_function": "relu",

    # ## Training & Optimizer Settings
    # Hyperparameters that control the training loop and optimization process.
    "steps": 20000,
    "batch_size": 128,
    "optimizer_type": "adamw",
    "learning_rate_max": 0.001,
    "lr_scheduler_type": "onecycle",
    "weight_decay": 0.01,
    "momentum": 0.9,

    # ## Audio Processing & Augmentation
    # Control how audio is processed and augmented to create diverse training data.
    "audio_processing": {
        "clip_length_samples": None,
        "autotune_length": {
            "enabled": True,
            "num_samples_to_inspect": 100,
            "duration_buffer_ms": 750,
            "min_allowable_length": 22000,
            "snap_to_min_tolerance": 4000
        }
    },
    "augmentation_rounds": 5,
    "augmentation_batch_size": 128,
    "min_snr_in_db": 5.0,
    "max_snr_in_db": 20.0,
    "augmentation_settings": {
        "BackgroundNoise": 0.75,
        "RIR": 0.4,
        "PitchShift": 0.3,
        "ColoredNoise": 0.25,
        "Gain": 1.0,
        "BandStopFilter": 0.1
    },

    # ## Synthetic Data Generation
    # Parameters for generating audio clips using Text-to-Speech (TTS).
    "generate_positive_samples": 2050,
    "generate_negative_samples": 4500,
    # List sensitive words or common false-alarm triggers to generate as negative data.
    "custom_negative_phrases": ['hello', 'ark', 'arcos', 'arfo', 'ar'],
    "custom_negative_per_phrase": 23,

    # ## Advanced & Miscellaneous Settings
    # Checkpointing, logging, and other fine-tuning parameters.
    "checkpoint_averaging_top_k": 5,
    "checkpointing": {
        "enabled": True,
        "interval_steps": 1000,
        "limit": 2
    },
    "early_stopping_patience": 0,
    "main_delta": 0.0001,
    "WARMUP_STEPS": 1500,
    "onnx_opset_version": 17,
    "show_training_summary": True,
    "debug_mode": True,
    "feature_gen_cpu_ratio": 1.0,
    "ema_alpha": 0.01,

    # ## Pipeline Control Switches
    # Master switches to enable or disable major stages of the pipeline.
    "generate_clips": True,
    "transform_clips": True,  # Don't forget to turn it off after finished.
    "train_model": True,
    "overwrite": False
}

# Write the config to a YAML file
config_path = "./config.yaml"
with open(config_path, 'w') as f:
    yaml.dump(config_dict, f, default_flow_style=False, sort_keys=False)

print(f"Configuration file saved to: {config_path}")

# %% [markdown]
# **Run Training!**

# %%
# @title Step 3.2: Run the Magic Command! 🚀
# This command will do everything: augment data, extract features, and train the model.
# It might take some time depending on the hardware (especially on a CPU).

from nanowakeword.trainer import train

args_list = [
    '--config_path', f'{config_path}',
]

print("Starting NanoWakeWord training...")

try:
    train(args_list)
    print("\n\nCONGRATULATIONS! (✿◕‿◕✿)")
    print("Your custom wake word model has been successfully trained!")

except Exception as e:
    print(f"\nAn error occurred during training: {e}")

# %% [markdown]
# ## What's Next?
#
# You have successfully trained your own custom wake word model!
#
# You can now download the `.onnx` file from the `trained_models` directory (check the file browser on the left) and use it in your own applications.
#
# For more advanced topics, such as using your own datasets or fine-tuning the configuration, please check out our full documentation on **[GitHub](https://github.com/arcosoph/nanowakeword)**.

# %% [markdown]
# ---
# ## Step 4: Save Your Model to Google Drive
#
# The final step is to save your trained model and performance graph to a safe and accessible place. Instead of a slow direct download, we will save the files directly to your Google Drive. This process is almost instantaneous.
#
# Run the cells below to:
# 1.  Connect your Google Drive account.
# 2.  Copy all the trained files into a new folder named `nanowakeword_models` in your Drive.

# %%
# @title Step 4.1: Connect to Google Drive
# This will ask for your permission to access your Google Drive.

from google.colab import drive
import os

try:
    drive.mount('/content/drive')
    print("\nGoogle Drive connected successfully!")
except Exception as e:
    print(f"An error occurred while connecting to Google Drive: {e}")

# %%
# @title Step 4.2: Copy Final Model and Artifacts to Google Drive 📂

import os
import shutil

# --- Configuration ---
# Get model_name and output_dir from the config_dict defined earlier
model_name = config_dict.get("model_name", "my_model")
output_dir = config_dict.get("output_dir", "./trained_models")

# --- Source and Destination Paths ---
# The source project directory containing all generated files
source_project_dir = os.path.join(output_dir, model_name)

# The destination folder in your Google Drive
drive_destination_dir = f"drive/MyDrive/nanowakeword_models/{model_name}"

# --- Start Copy Process ---
print("Starting the process to copy trained files to Google Drive...")

# Check if the source directory exists
if not os.path.exists(source_project_dir):
    print(f"\n❌ ERROR: Source directory not found at '{source_project_dir}'")
    print("This indicates that the training process did not create the expected output folder.")
    print("Please ensure the training step completed successfully before running this cell.")
else:
    # If an old folder exists in Drive, remove it to ensure a clean copy
    if os.path.exists(drive_destination_dir):
        print(f"🔄 Found an existing folder in Drive. Removing it for a fresh copy: '{drive_destination_dir}'")
        shutil.rmtree(drive_destination_dir)

    # --- Copy the entire project folder ---
    # This is much simpler and more reliable than copying individual files.
    # It preserves the professional directory structure.
    try:
        shutil.copytree(source_project_dir, drive_destination_dir)

        print("\n" + "="*50)
        print("✅ SUCCESS! All files have been saved to your Google Drive.")
        print("="*50)
        print(f"\nYour complete project, including the model and performance graphs, can be found in:")
        print(f"➡️ '{drive_destination_dir}'")

        # Optional: List the contents of the new folder in Drive for verification
        print("\nContents of the saved folder:")
        for root, dirs, files in os.walk(drive_destination_dir):
            level = root.replace(drive_destination_dir, '').count(os.sep)
            indent = ' ' * 4 * (level)
            print(f"{indent}{os.path.basename(root)}/")
            sub_indent = ' ' * 4 * (level + 1)
            for f in files:
                print(f"{sub_indent}{f}")

    except Exception as e:
        print(f"\n❌ ERROR: An unexpected error occurred during the copy process.")
        print(f"Details: {e}")
